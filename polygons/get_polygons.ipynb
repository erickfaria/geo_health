# %%
import geobr
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib inline

# %%
# Municipality of Sao Paulo
muni = geobr.read_municipality(code_muni=3550308, year=2010)
# Out:
# c:\Users\erick.faria\AppData\Local\miniconda3\envs\python-geo\Lib\site-packages\geopandas\array.py:93: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   aout[:] = out

# %%
muni
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File c:\Users\erick.faria\AppData\Local\miniconda3\envs\python-geo\Lib\site-packages\IPython\core\formatters.py:708, in PlainTextFormatter.__call__(self, obj)
#     701 stream = StringIO()
#     702 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     703     self.max_width, self.newline,
#     704     max_seq_length=self.max_seq_length,
#     705     singleton_pprinters=self.singleton_printers,
#     706     type_pprinters=self.type_printers,
#     707     deferred_pprinters=self.deferred_printers)
# --> 708 printer.pretty(obj)
#     709 printer.flush()
#     710 return stream.getvalue()
#
# File c:\Users\erick.faria\AppData\Local\miniconda3\envs\python-geo\Lib\site-packages\IPython\lib\pretty.py:410, in RepresentationPrinter.pretty(self, obj)
#     407                         return meth(obj, self, cycle)
#     408                 if cls is not object \
#     409                         and callable(cls.__dict__.get('__repr__')):
# --> 410                     return _repr_pprint(obj, self, cycle)
#     412     return _default_pprint(obj, self, cycle)
#     413 finally:
#
# File c:\Users\erick.faria\AppData\Local\miniconda3\envs\python-geo\Lib\site-packages\IPython\lib\pretty.py:778, in _repr_pprint(obj, p, cycle)
#     776 """A pprint that just redirects to the normal repr function."""
#     777 # Find newlines and replace them with p.break_()
# --> 778 output = repr(obj)
#     779 lines = output.splitlines()
#     780 with p.group():
#
# File c:\Users\erick.faria\AppData\Local\miniconda3\envs\python-geo\Lib\site-packages\pandas\core\frame.py:1133, in DataFrame.__repr__(self)
#    1130     return buf.getvalue()
#    1132 repr_params = fmt.get_dataframe_repr_params()
# -> 1133 return self.to_string(**repr_params)
#
# File c:\Users\erick.faria\AppData\Local\miniconda3\envs\python-geo\Lib\site-packages\pandas\core\frame.py:1310, in DataFrame.to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, max_cols, show_dimensions, decimal, line_width, min_rows, max_colwidth, encoding)
#    1291 with option_context("display.max_colwidth", max_colwidth):
#    1292     formatter = fmt.DataFrameFormatter(
#    1293         self,
#    1294         columns=columns,
#    (...)
#    1308         decimal=decimal,
#    1309     )
# -> 1310     return fmt.DataFrameRenderer(formatter).to_string(
#    1311         buf=buf,
#    1312         encoding=encoding,
#    1313         line_width=line_width,
#    1314     )
#
# File c:\Users\erick.faria\AppData\Local\miniconda3\envs\python-geo\Lib\site-packages\pandas\io\formats\format.py:1100, in DataFrameRenderer.to_string(self, buf, encoding, line_width)
#    1097 from pandas.io.formats.string import StringFormatter
#    1099 string_formatter = StringFormatter(self.fmt, line_width=line_width)
# -> 1100 string = string_formatter.to_string()
#    1101 return save_to_buffer(string, buf=buf, encoding=encoding)
#
# File c:\Users\erick.faria\AppData\Local\miniconda3\envs\python-geo\Lib\site-packages\pandas\io\formats\string.py:29, in StringFormatter.to_string(self)
#      28 def to_string(self) -> str:
# ---> 29     text = self._get_string_representation()
#      30     if self.fmt.should_show_dimensions:
#      31         text = "".join([text, self.fmt.dimensions_info])
#
# File c:\Users\erick.faria\AppData\Local\miniconda3\envs\python-geo\Lib\site-packages\pandas\io\formats\string.py:44, in StringFormatter._get_string_representation(self)
#      41 if self.fmt.frame.empty:
#      42     return self._empty_info_line
# ---> 44 strcols = self._get_strcols()
#      46 if self.line_width is None:
#      47     # no need to wrap around just print the whole frame
#      48     return self.adj.adjoin(1, *strcols)
#
# File c:\Users\erick.faria\AppData\Local\miniconda3\envs\python-geo\Lib\site-packages\pandas\io\formats\string.py:35, in StringFormatter._get_strcols(self)
#      34 def _get_strcols(self) -> list[list[str]]:
# ---> 35     strcols = self.fmt.get_strcols()
#      36     if self.fmt.is_truncated:
#      37         strcols = self._insert_dot_separators(strcols)
#
# File c:\Users\erick.faria\AppData\Local\miniconda3\envs\python-geo\Lib\site-packages\pandas\io\formats\format.py:615, in DataFrameFormatter.get_strcols(self)
#     611 def get_strcols(self) -> list[list[str]]:
#     612     """
#     613     Render a DataFrame to a list of columns (as lists of strings).
#     614     """
# --> 615     strcols = self._get_strcols_without_index()
#     617     if self.index:
#     618         str_index = self._get_formatted_index(self.tr_frame)
#
# File c:\Users\erick.faria\AppData\Local\miniconda3\envs\python-geo\Lib\site-packages\pandas\io\formats\format.py:879, in DataFrameFormatter._get_strcols_without_index(self)
#     875 cheader = str_columns[i]
#     876 header_colwidth = max(
#     877     int(self.col_space.get(c, 0)), *(self.adj.len(x) for x in cheader)
#     878 )
# --> 879 fmt_values = self.format_col(i)
#     880 fmt_values = _make_fixed_width(
#     881     fmt_values, self.justify, minimum=header_colwidth, adj=self.adj
#     882 )
#     884 max_len = max(*(self.adj.len(x) for x in fmt_values), header_colwidth)
#
# File c:\Users\erick.faria\AppData\Local\miniconda3\envs\python-geo\Lib\site-packages\pandas\io\formats\format.py:893, in DataFrameFormatter.format_col(self, i)
#     891 frame = self.tr_frame
#     892 formatter = self._get_formatter(i)
# --> 893 return format_array(
#     894     frame.iloc[:, i]._values,
#     895     formatter,
#     896     float_format=self.float_format,
#     897     na_rep=self.na_rep,
#     898     space=self.col_space.get(frame.columns[i]),
#     899     decimal=self.decimal,
#     900     leading_space=self.index,
#     901 )
#
# File c:\Users\erick.faria\AppData\Local\miniconda3\envs\python-geo\Lib\site-packages\pandas\io\formats\format.py:1296, in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting, fallback_formatter)
#    1280     digits = get_option("display.precision")
#    1282 fmt_obj = fmt_klass(
#    1283     values,
#    1284     digits=digits,
#    (...)
#    1293     fallback_formatter=fallback_formatter,
#    1294 )
# -> 1296 return fmt_obj.get_result()
#
# File c:\Users\erick.faria\AppData\Local\miniconda3\envs\python-geo\Lib\site-packages\pandas\io\formats\format.py:1329, in GenericArrayFormatter.get_result(self)
#    1328 def get_result(self) -> list[str]:
# -> 1329     fmt_values = self._format_strings()
#    1330     return _make_fixed_width(fmt_values, self.justify)
#
# File c:\Users\erick.faria\AppData\Local\miniconda3\envs\python-geo\Lib\site-packages\pandas\io\formats\format.py:1658, in ExtensionArrayFormatter._format_strings(self)
#    1656 fallback_formatter = None
#    1657 if formatter is None:
# -> 1658     fallback_formatter = values._formatter(boxed=True)
#    1660 if isinstance(values, Categorical):
#    1661     # Categorical is special for now, so that we can preserve tzinfo
#    1662     array = values._internal_get_values()
#
# File c:\Users\erick.faria\AppData\Local\miniconda3\envs\python-geo\Lib\site-packages\geopandas\array.py:1039, in GeometryArray._formatter(self, boxed)
#    1035 precision = geopandas.options.display_precision
#    1036 if precision is None:
#    1037     # dummy heuristic based on 10 first geometries that should
#    1038     # work in most cases
# -> 1039     xmin, ymin, xmax, ymax = self[~self.isna()][:10].total_bounds
#    1040     if (
#    1041         (-180 <= xmin <= 180)
#    1042         and (-180 <= xmax <= 180)
#    (...)
#    1045     ):
#    1046         # geographic coordinates
#    1047         precision = 5
#
# File c:\Users\erick.faria\AppData\Local\miniconda3\envs\python-geo\Lib\site-packages\geopandas\array.py:778, in GeometryArray.total_bounds(self)
#     774 if len(self) == 0:
#     775     # numpy 'min' cannot handle empty arrays
#     776     # TODO with numpy >= 1.15, the 'initial' argument can be used
#     777     return np.array([np.nan, np.nan, np.nan, np.nan])
# --> 778 b = self.bounds
#     779 return np.array(
#     780     (
#     781         b[:, 0].min(),  # minx
#    (...)
#     785     )
#     786 )
#
# File c:\Users\erick.faria\AppData\Local\miniconda3\envs\python-geo\Lib\site-packages\geopandas\array.py:763, in GeometryArray.bounds(self)
#     759     return np.empty((0, 4), dtype="float64")
#     760 # need to explicitly check for empty (in addition to missing) geometries,
#     761 # as those return an empty tuple, not resulting in a 2D array
#     762 bounds = np.array(
# --> 763     [
#     764         geom.bounds
#     765         if not (geom is None or geom.is_empty)
#     766         else (np.nan, np.nan, np.nan, np.nan)
#     767         for geom in self.data
#     768     ]
#     769 )
#     770 return bounds
#
# File c:\Users\erick.faria\AppData\Local\miniconda3\envs\python-geo\Lib\site-packages\geopandas\array.py:764, in <listcomp>(.0)
#     759     return np.empty((0, 4), dtype="float64")
#     760 # need to explicitly check for empty (in addition to missing) geometries,
#     761 # as those return an empty tuple, not resulting in a 2D array
#     762 bounds = np.array(
#     763     [
# --> 764         geom.bounds
#     765         if not (geom is None or geom.is_empty)
#     766         else (np.nan, np.nan, np.nan, np.nan)
#     767         for geom in self.data
#     768     ]
#     769 )
#     770 return bounds
#
# File c:\Users\erick.faria\AppData\Local\miniconda3\envs\python-geo\Lib\site-packages\shapely\geometry\base.py:475, in BaseGeometry.bounds(self)
#     473     return ()
#     474 else:
# --> 475     return self.impl['bounds'](self)
#
# File c:\Users\erick.faria\AppData\Local\miniconda3\envs\python-geo\Lib\site-packages\shapely\coords.py:187, in BoundsOp.__call__(self, this)
#     185 def __call__(self, this):
#     186     self._validate(this)
# --> 187     env = this.envelope
#     188     if env.geom_type == 'Point':
#     189         return env.bounds
#
# File c:\Users\erick.faria\AppData\Local\miniconda3\envs\python-geo\Lib\site-packages\shapely\geometry\base.py:500, in BaseGeometry.envelope(self)
#     497 @property
#     498 def envelope(self):
#     499     """A figure that envelopes the geometry"""
# --> 500     return geom_factory(self.impl['envelope'](self))
#
# File c:\Users\erick.faria\AppData\Local\miniconda3\envs\python-geo\Lib\site-packages\shapely\topology.py:81, in UnaryTopologicalOp.__call__(self, this, *args)
#      79 def __call__(self, this, *args):
#      80     self._validate(this)
# ---> 81     return self.fn(this._geom, *args)
#
# OSError: exception: access violation writing 0x00007FF96FE562D8
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File c:\Users\erick.faria\AppData\Local\miniconda3\envs\python-geo\Lib\site-packages\IPython\core\formatters.py:344, in BaseFormatter.__call__(self, obj)
#     342     method = get_real_method(obj, self.print_method)
#     343     if method is not None:
# --> 344         return method()
#     345     return None
#     346 else:
#
# File c:\Users\erick.faria\AppData\Local\miniconda3\envs\python-geo\Lib\site-packages\pandas\core\frame.py:1175, in DataFrame._repr_html_(self)
#    1153     show_dimensions = get_option("display.show_dimensions")
#    1155     formatter = fmt.DataFrameFormatter(
#    1156         self,
#    1157         columns=None,
#    (...)
#    1173         decimal=".",
#    1174     )
# -> 1175     return fmt.DataFrameRenderer(formatter).to_html(notebook=True)
#    1176 else:
#    1177     return None
#
# File c:\Users\erick.faria\AppData\Local\miniconda3\envs\python-geo\Lib\site-packages\pandas\io\formats\format.py:1074, in DataFrameRenderer.to_html(self, buf, encoding, classes, notebook, border, table_id, render_links)
#    1065 Klass = NotebookFormatter if notebook else HTMLFormatter
#    1067 html_formatter = Klass(
#    1068     self.fmt,
#    1069     classes=classes,
#    (...)
#    1072     render_links=render_links,
#    1073 )
# -> 1074 string = html_formatter.to_string()
#    1075 return save_to_buffer(string, buf=buf, encoding=encoding)
#
# File c:\Users\erick.faria\AppData\Local\miniconda3\envs\python-geo\Lib\site-packages\pandas\io\formats\html.py:88, in HTMLFormatter.to_string(self)
#      87 def to_string(self) -> str:
# ---> 88     lines = self.render()
#      89     if any(isinstance(x, str) for x in lines):
#      90         lines = [str(x) for x in lines]
#
# File c:\Users\erick.faria\AppData\Local\miniconda3\envs\python-geo\Lib\site-packages\pandas\io\formats\html.py:642, in NotebookFormatter.render(self)
#     640 self.write("<div>")
#     641 self.write_style()
# --> 642 super().render()
#     643 self.write("</div>")
#     644 return self.elements
#
# File c:\Users\erick.faria\AppData\Local\miniconda3\envs\python-geo\Lib\site-packages\pandas\io\formats\html.py:94, in HTMLFormatter.render(self)
#      93 def render(self) -> list[str]:
# ---> 94     self._write_table()
#      96     if self.should_show_dimensions:
#      97         by = chr(215)  # ×  # noqa: RUF003
#
# File c:\Users\erick.faria\AppData\Local\miniconda3\envs\python-geo\Lib\site-packages\pandas\io\formats\html.py:269, in HTMLFormatter._write_table(self, indent)
#     266 if self.fmt.header or self.show_row_idx_names:
#     267     self._write_header(indent + self.indent_delta)
# --> 269 self._write_body(indent + self.indent_delta)
#     271 self.write("</table>", indent)
#
# File c:\Users\erick.faria\AppData\Local\miniconda3\envs\python-geo\Lib\site-packages\pandas\io\formats\html.py:417, in HTMLFormatter._write_body(self, indent)
#     415 def _write_body(self, indent: int) -> None:
#     416     self.write("<tbody>", indent)
# --> 417     fmt_values = self._get_formatted_values()
#     419     # write values
#     420     if self.fmt.index and isinstance(self.frame.index, MultiIndex):
#
# File c:\Users\erick.faria\AppData\Local\miniconda3\envs\python-geo\Lib\site-packages\pandas\io\formats\html.py:606, in NotebookFormatter._get_formatted_values(self)
#     605 def _get_formatted_values(self) -> dict[int, list[str]]:
# --> 606     return {i: self.fmt.format_col(i) for i in range(self.ncols)}
#
# File c:\Users\erick.faria\AppData\Local\miniconda3\envs\python-geo\Lib\site-packages\pandas\io\formats\html.py:606, in <dictcomp>(.0)
#     605 def _get_formatted_values(self) -> dict[int, list[str]]:
# --> 606     return {i: self.fmt.format_col(i) for i in range(self.ncols)}
#
# File c:\Users\erick.faria\AppData\Local\miniconda3\envs\python-geo\Lib\site-packages\pandas\io\formats\format.py:893, in DataFrameFormatter.format_col(self, i)
#     891 frame = self.tr_frame
#     892 formatter = self._get_formatter(i)
# --> 893 return format_array(
#     894     frame.iloc[:, i]._values,
#     895     formatter,
#     896     float_format=self.float_format,
#     897     na_rep=self.na_rep,
#     898     space=self.col_space.get(frame.columns[i]),
#     899     decimal=self.decimal,
#     900     leading_space=self.index,
#     901 )
#
# File c:\Users\erick.faria\AppData\Local\miniconda3\envs\python-geo\Lib\site-packages\pandas\io\formats\format.py:1296, in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space, quoting, fallback_formatter)
#    1280     digits = get_option("display.precision")
#    1282 fmt_obj = fmt_klass(
#    1283     values,
#    1284     digits=digits,
#    (...)
#    1293     fallback_formatter=fallback_formatter,
#    1294 )
# -> 1296 return fmt_obj.get_result()
#
# File c:\Users\erick.faria\AppData\Local\miniconda3\envs\python-geo\Lib\site-packages\pandas\io\formats\format.py:1329, in GenericArrayFormatter.get_result(self)
#    1328 def get_result(self) -> list[str]:
# -> 1329     fmt_values = self._format_strings()
#    1330     return _make_fixed_width(fmt_values, self.justify)
#
# File c:\Users\erick.faria\AppData\Local\miniconda3\envs\python-geo\Lib\site-packages\pandas\io\formats\format.py:1658, in ExtensionArrayFormatter._format_strings(self)
#    1656 fallback_formatter = None
#    1657 if formatter is None:
# -> 1658     fallback_formatter = values._formatter(boxed=True)
#    1660 if isinstance(values, Categorical):
#    1661     # Categorical is special for now, so that we can preserve tzinfo
#    1662     array = values._internal_get_values()
#
# File c:\Users\erick.faria\AppData\Local\miniconda3\envs\python-geo\Lib\site-packages\geopandas\array.py:1039, in GeometryArray._formatter(self, boxed)
#    1035 precision = geopandas.options.display_precision
#    1036 if precision is None:
#    1037     # dummy heuristic based on 10 first geometries that should
#    1038     # work in most cases
# -> 1039     xmin, ymin, xmax, ymax = self[~self.isna()][:10].total_bounds
#    1040     if (
#    1041         (-180 <= xmin <= 180)
#    1042         and (-180 <= xmax <= 180)
#    (...)
#    1045     ):
#    1046         # geographic coordinates
#    1047         precision = 5
#
# File c:\Users\erick.faria\AppData\Local\miniconda3\envs\python-geo\Lib\site-packages\geopandas\array.py:778, in GeometryArray.total_bounds(self)
#     774 if len(self) == 0:
#     775     # numpy 'min' cannot handle empty arrays
#     776     # TODO with numpy >= 1.15, the 'initial' argument can be used
#     777     return np.array([np.nan, np.nan, np.nan, np.nan])
# --> 778 b = self.bounds
#     779 return np.array(
#     780     (
#     781         b[:, 0].min(),  # minx
#    (...)
#     785     )
#     786 )
#
# File c:\Users\erick.faria\AppData\Local\miniconda3\envs\python-geo\Lib\site-packages\geopandas\array.py:763, in GeometryArray.bounds(self)
#     759     return np.empty((0, 4), dtype="float64")
#     760 # need to explicitly check for empty (in addition to missing) geometries,
#     761 # as those return an empty tuple, not resulting in a 2D array
#     762 bounds = np.array(
# --> 763     [
#     764         geom.bounds
#     765         if not (geom is None or geom.is_empty)
#     766         else (np.nan, np.nan, np.nan, np.nan)
#     767         for geom in self.data
#     768     ]
#     769 )
#     770 return bounds
#
# File c:\Users\erick.faria\AppData\Local\miniconda3\envs\python-geo\Lib\site-packages\geopandas\array.py:764, in <listcomp>(.0)
#     759     return np.empty((0, 4), dtype="float64")
#     760 # need to explicitly check for empty (in addition to missing) geometries,
#     761 # as those return an empty tuple, not resulting in a 2D array
#     762 bounds = np.array(
#     763     [
# --> 764         geom.bounds
#     765         if not (geom is None or geom.is_empty)
#     766         else (np.nan, np.nan, np.nan, np.nan)
#     767         for geom in self.data
#     768     ]
#     769 )
#     770 return bounds
#
# File c:\Users\erick.faria\AppData\Local\miniconda3\envs\python-geo\Lib\site-packages\shapely\geometry\base.py:475, in BaseGeometry.bounds(self)
#     473     return ()
#     474 else:
# --> 475     return self.impl['bounds'](self)
#
# File c:\Users\erick.faria\AppData\Local\miniconda3\envs\python-geo\Lib\site-packages\shapely\coords.py:187, in BoundsOp.__call__(self, this)
#     185 def __call__(self, this):
#     186     self._validate(this)
# --> 187     env = this.envelope
#     188     if env.geom_type == 'Point':
#     189         return env.bounds
#
# File c:\Users\erick.faria\AppData\Local\miniconda3\envs\python-geo\Lib\site-packages\shapely\geometry\base.py:500, in BaseGeometry.envelope(self)
#     497 @property
#     498 def envelope(self):
#     499     """A figure that envelopes the geometry"""
# --> 500     return geom_factory(self.impl['envelope'](self))
#
# File c:\Users\erick.faria\AppData\Local\miniconda3\envs\python-geo\Lib\site-packages\shapely\topology.py:81, in UnaryTopologicalOp.__call__(self, this, *args)
#      79 def __call__(self, this, *args):
#      80     self._validate(this)
# ---> 81     return self.fn(this._geom, *args)
#
# OSError: exception: access violation reading 0x00000000000000A1
